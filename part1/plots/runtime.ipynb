# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("../results/runtime.csv",delimiter=",")
ax = sns.lineplot( data=df, x='N', y='Running time', ci="Standard deviation", hue="Method")
ax.set(yLabel="Average query time")
ax.get_figure().savefig("runtime-results.png")
